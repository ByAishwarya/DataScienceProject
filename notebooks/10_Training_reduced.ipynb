# %%
import pandas as pd
import numpy as np
import time
import os
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import (
    mean_absolute_error, 
    mean_squared_error, 
    r2_score, 
    median_absolute_error, 
    explained_variance_score, 
    max_error
)
from tqdm.auto import tqdm

# %%
# 1. LOAD REDUCED FEATURE DATASETS
X_train_reduced = pd.read_csv('../data/X_train_reduced.csv')
X_test_reduced = pd.read_csv('../data/X_test_reduced.csv')
y_train = pd.read_csv('../data/y_train.csv').values.ravel()
y_test = pd.read_csv('../data/y_test.csv').values.ravel()

# %%
# 2. DEFINE PIPELINE
def create_pipeline(model):
    return Pipeline([
        ('scaler', StandardScaler()),
        ('regressor', model)
    ])

# 3. INITIALIZE MODELS
models = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=1.0, random_state=42),
    'Lasso Regression': Lasso(alpha=0.1, random_state=42, max_iter=10000),
    'Decision Tree': DecisionTreeRegressor(max_depth=10, random_state=42),
    'Random Forest': RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42, n_jobs=-1),
    'Gradient Boosting': GradientBoostingRegressor(n_estimators=100, random_state=42)
}

# 4. TRAIN AND EVALUATE
results = []
threshold = 15

for name, model in tqdm(models.items(), desc="Evaluating Models on Reduced Features"):
    pipe = create_pipeline(model)
    
    # Training Time
    start_train = time.time()
    pipe.fit(X_train_reduced, y_train)
    training_time = time.time() - start_train
    
    # Prediction Time
    start_pred = time.time()
    y_pred = pipe.predict(X_test_reduced)
    prediction_time = time.time() - start_pred
    
    # Metric Calculations
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    med_ae = median_absolute_error(y_test, y_pred)
    var_score = explained_variance_score(y_test, y_pred)
    m_error = max_error(y_test, y_pred)
    within_threshold = np.mean(np.abs(y_test - y_pred) <= threshold) * 100
    
    results.append({
        'Model': name,
        'MAE': round(mae, 2),
        'RMSE': round(rmse, 2),
        'R2 Score': round(r2, 4),
        'Median AE': round(med_ae, 2),
        'Variance Score': round(var_score, 4),
        'Max Error': round(m_error, 2),
        'Acc ±15 (%)': round(within_threshold, 2),
        'Train Time (s)': round(training_time, 4),
        'Pred Time (s)': round(prediction_time, 4)
    })

# 5. DISPLAY RESULTS
performance_df = pd.DataFrame(results)
print("\n" + "="*120)
print("MODEL PERFORMANCE ON REDUCED FEATURES")
print("="*120)
print(performance_df.to_string(index=False))
print("="*120)

# 6. BEST MODELS BY METRIC
print("\nBEST PERFORMING MODELS:")
print("-" * 50)
metrics_lower_better = ['MAE', 'RMSE', 'Median AE', 'Max Error', 'Train Time (s)', 'Pred Time (s)']
metrics_higher_better = ['R2 Score', 'Variance Score', 'Acc ±15 (%)']

for metric in metrics_lower_better:
    best_model = performance_df.loc[performance_df[metric].idxmin(), 'Model']
    best_value = performance_df[metric].min()
    print(f"  {metric:20s}: {best_model:20s} ({best_value})")

for metric in metrics_higher_better:
    best_model = performance_df.loc[performance_df[metric].idxmax(), 'Model']
    best_value = performance_df[metric].max()
    print(f"  {metric:20s}: {best_model:20s} ({best_value})")

# 7. SAVE RESULTS (Create directory if needed)
os.makedirs('../results', exist_ok=True)
performance_df.to_csv('../results/model_comparison_reduced_features.csv', index=False)
print("\n✓ Results saved to '../results/model_comparison_reduced_features.csv'")
# Out:
# Evaluating Models on Reduced Features:   0%|          | 0/6 [00:00<?, ?it/s]
# ========================================================================================================================
# MODEL PERFORMANCE ON REDUCED FEATURES
# ========================================================================================================================
#             Model   MAE  RMSE  R2 Score  Median AE  Variance Score  Max Error  Acc ±15 (%)  Train Time (s)  Pred Time (s)
# Linear Regression 11.99 16.84    0.3219       7.72          0.3219      80.09        71.09          0.0661         0.0070
#  Ridge Regression 11.99 16.84    0.3219       7.72          0.3219      80.09        71.09          0.0656         0.0058
#  Lasso Regression 12.00 16.84    0.3220       7.74          0.3220      80.80        71.13          0.1233         0.0070
#     Decision Tree 11.59 16.69    0.3343       7.13          0.3343      87.00        72.57          1.2940         0.0165
#     Random Forest 11.31 16.05    0.3844       7.09          0.3844      83.41        73.12          8.3728         0.1417
# Gradient Boosting 11.90 16.67    0.3352       7.76          0.3352      79.43        71.39         39.1857         0.0663
# ========================================================================================================================
#
# BEST PERFORMING MODELS:
# --------------------------------------------------
#   MAE                 : Random Forest        (11.31)
#   RMSE                : Random Forest        (16.05)
#   Median AE           : Random Forest        (7.09)
#   Max Error           : Gradient Boosting    (79.43)
#   Train Time (s)      : Ridge Regression     (0.0656)
#   Pred Time (s)       : Ridge Regression     (0.0058)
#   R2 Score            : Random Forest        (0.3844)
#   Variance Score      : Random Forest        (0.3844)
#   Acc ±15 (%)         : Random Forest        (73.12)
#
# ✓ Results saved to '../results/model_comparison_reduced_features.csv'
