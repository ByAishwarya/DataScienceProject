# %% [markdown]
# ## 🎯 **Project Goal**
# Predict the **popularity score (0-100)** of Spotify tracks based on their audio features.

# %% [markdown]
# Regression Task: Target Variable is "Popularity Score".
# which will vary between 0 to 100.
# **Continuous numerical value**

# %% [markdown]
# ###  **Dataset Source**
# Spotify Tracks Dataset - based on Spotify Web API audio features
# -📊 **Link:** [Kaggle - Spotify Music Dataset](https://www.kaggle.com/datasets/solomonameh/spotify-music-dataset)
#
# ---
#
# **Author:** Aishwarya Sharma
# **Date:** January 12, 2025
# **Project Type:** Regression (Continuous Target Variable)

# %% [markdown]
# <p align="center">
#  <img src="../assets/dividerlines.png" width="600"/>
# </p>
